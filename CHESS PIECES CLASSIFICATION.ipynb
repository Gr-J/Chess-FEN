# %%
import fastai
from fastai.vision.all import *

# %%
data_dir = Path("C:\Datasets\CHESS_PIECES")

# %%
dls = ImageDataLoaders.from_folder(data_dir, valid_pct=0.2, num_workers=0)

# %% [markdown]
# dls.valid_ds.items[:3]

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to C:\Users\jgriv/.cache\torch\hub\checkpoints\resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))

# %% [markdown]
# learn.lr_find()

# %%
learn.fine_tune(2, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.218077</td>
#       <td>0.084070</td>
#       <td>0.026124</td>
#       <td>07:11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.036558</td>
#       <td>0.014041</td>
#       <td>0.001989</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.004429</td>
#       <td>0.000377</td>
#       <td>0.000133</td>
#       <td>01:16</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# learn.show_results()

# %% [markdown]
# interp = Interpretation.from_learner(learn)

# %% [markdown]
# interp.plot_top_losses(9, figsize=(15,10))

# %% [markdown]
# learn.save('classification-1')

# %%
learn.export()
